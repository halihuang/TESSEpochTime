# %%
from model_util import plot_pred_vs_true, plot_pred_ztf_max, load_model
from model_config import params

import json


model_name = "20220802-031619"
model = load_model(model_name)

plot_pred_vs_true(params.test_filenames, model)
# plot_pred_ztf_max(params.test_filenames, model, save="True", save_dir="./TESS_data/pred_plots/")
